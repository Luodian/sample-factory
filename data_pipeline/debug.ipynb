# %%
import pandas as pd

df = pd.read_parquet("/opt/tiger/sample-factory/data_pipeline/atari_training_data.parquet")
print(f"Dataset shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")
print(f"Total episodes: {len(df)}")

# Show structure of first row
row = df.iloc[0]
# Out:
# Dataset shape: (481, 7)
# Columns: ['inputs', 'images', 'images_front', 'environment', 'episode', 'num_frames', 'randomness']
# Total episodes: 481

# %%
import json
row["inputs"]
# Out:
# array([{'has_loss': 0, 'image_index': None, 'text': 'Atari Alien Environment (randomness=0.2)', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 0.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'up', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 1.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 2.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 3.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downleft', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 4.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'left', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 5.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'right', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 6.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downright', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 7.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'upleftfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 8.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downright', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 9.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'upleft', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 10.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'leftfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 11.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 12.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'upleft', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 13.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 14.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 15.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 16.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'fire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 17.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'left', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 18.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 19.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'down', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 20.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'uprightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 21.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 22.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 23.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 24.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'down', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 25.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 26.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'down', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 27.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 28.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 29.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'left', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 30.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 31.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 32.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 33.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 34.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 35.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 36.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 37.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 38.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'up', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 39.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 40.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 41.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downleft', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 42.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 43.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'uprightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 44.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'down', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 45.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 46.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 47.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 48.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 49.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 50.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'rightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 51.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 52.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 53.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 54.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 55.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 56.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'down', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 57.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 58.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 59.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 60.0, 'text': None, 'type': 'image_gen'}],
#       dtype=object)
