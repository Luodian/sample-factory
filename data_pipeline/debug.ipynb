# %%
import pandas as pd

df = pd.read_parquet("/mnt/bn/seed-aws-va/brianli/prod/contents/atari_2B/parquet_individual/atari_alien.parquet")
print(f"Dataset shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")
print(f"Total episodes: {len(df)}")

# Show structure of first row
row = df.iloc[0]
# Out:
# Dataset shape: (1, 7)
# Columns: ['inputs', 'images', 'images_front', 'environment', 'episode', 'num_frames', 'randomness']
# Total episodes: 1

# %%
import json
row["inputs"]
# Out:
# array([{'has_loss': 0, 'image_index': None, 'text': 'Game: Alien (Maze/Shooter). View: Top-down 160×210. Initial state: Player starts at bottom of maze. Player controls: Spaceship. Mission: Navigate mazes, collect eggs, avoid/destroy aliens. Mechanics: 8-directional movement, Shooting, Egg collection. Hazards: Aliens, Pulsar zones, Time limits. HUD/Score visible at top. Status/Lives visible at bottom', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 0.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'up', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 1.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'downrightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 2.0, 'text': None, 'type': 'image_gen'},
#        {'has_loss': 0, 'image_index': None, 'text': 'uprightfire', 'type': 'text'},
#        {'has_loss': 1, 'image_index': 3.0, 'text': None, 'type': 'image_gen'},
# ...

# %%
import pandas as pd

df = pd.read_parquet("/opt/tiger/minigirid_v0_with_rules/BabyAI-GoToLocalS6N3-v0_rand0.2.w0.size1000_1756566136307_3701674_03e944be.parquet")
print(f"Dataset shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")
print(f"Total episodes: {len(df)}")

# Show structure of first row
row = df.iloc[0]

import json

json.loads(row["inputs"])
# Out:
# Dataset shape: (1000, 3)
# Columns: ['inputs', 'images', 'images_front']
# Total episodes: 1000
# [{'type': 'text',
#   'has_loss': 0,
# ...
